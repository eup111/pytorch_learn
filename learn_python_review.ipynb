# %% [markdown]
# <a href="https://www.kaggle.com/code/eupphh/python-re?scriptVersionId=292889750" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# %% [code]
# s1 = "b"
# s2 = "d"
# n1 = 10
# s3 = f"a{s1}c{s2}efg{n1}"
# print(s3)
# print(s1+s2)

# s4 = "aa\tbb\nabcd"
# print(s4)

# s1 = "a"
# s2 = "b"
# print(s1==s2)
#
# set1 = [1,2,3]
# print(2 in set1)

# s = '12'
# i = 1
# f = 2.22
# b = True
# print(str(i))
# print(str(f))
# print(str(b))
#
# print(int(s))
# print(int(f))
# print(int(b))
#
# print(float(s))
# print(float(i))
# print(float(b))
#
# print(bool(s))
# print(bool(i))
# print(bool(f))


# set1 = set([1, 2, 3, 4, 5,1,3,5])
# print(set1)
# set2 = {"a", "b", "c", "d","a","b"}
# print(set2)

# t1 = (1,"a",True,{"a","b","c","a"},(1,2,3),[1,2,3],{1:'a',2:'b',3:'c'})
# print(t1)
# s1 = "d"
# print(f"abc{s1}")
# print("abc",s1)

# a,b = 1,2
# print(a,b)
# b,a = a,b
# print(a,b)
# t1 = 1,2,3,4,5
# a,b,*rest = t1
# print(a)
# print(b)
# print(rest)

# l1 =[1,"a",True,{"a","b","c","a"},(1,2,3),[1,2,3],{1:'a',2:'b',3:'c'}]
# print(l1[:2])
# print(l1[2:])
# print(l1[1:3])
# print(l1[1::2])

# l1 = [1,2,3,4,5]
# print(l1+ [1,2])
# print(l1*2)


# l1 = {'a':1,'b':2,1:3}
# print(l1[1])

# l1['c']=4
# l1['d']=5
# print(l1)
# l2 = [1,2,3]

# for i in l1.keys():
#     print(i)
#
# for i in l1.values():
#     print(i)
# for k,v in l1.items():
#     print(k,v)

# a = [i*i for i in l2 if i%2==0]
# print(a)

# set1 = {1,2,3}
# list1 = [1,2,3]
# tuple1 = (1,2,3)
# print(dict(zip(['a','b','c'],set1)))
# print(dict(zip(['a','b','c'],list1)))
# print(dict(zip(['a','b','c'],tuple1)))

# def func(a,b,c,e=1,**kwargs):
#     """
#     :param a:
#     :param b:
#     :param c:
#     :param kwargs:
#     :return:
#     """
#     print(a,b,c,kwargs,e)
#     return a+b+c
#
# func(a=1,b=2,c=3,d=4)
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age
        self.owner = 'ow'
    def info(self):
        print("INFO:",self.name,self.age,self.owner)

d1 = Dog("D",1)
d1.info()
print(d1.name)

class Dog2(Dog):
    def __init__(self,name,age):
        super().__init__(name,age)
    def info(self):
        print("dog2:")
        super().info()

d2 = Dog2("D2",1)
d2.info()

class Dog3():
    def __init__(self,name,age):
        self.name = name
        self.age = age
        self.dog = Dog2("D2",1)

d3 = Dog3("D3",1)
d3.dog.info()
